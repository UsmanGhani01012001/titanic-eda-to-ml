# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('Titanic-Dataset.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    int64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     891 non-null    object
# dtypes: float64(1), int64(6), object(4)
# memory usage: 76.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.544332    0.523008
# std     257.353842    0.486592    0.836071   13.013778    1.102743
# min       1.000000    0.000000    1.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   29.000000    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             71
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Embarked         3
# dtype: int64

# %%
sns.countplot(x='Sex', data=df, palette='pastel')
plt.title('Passenger Count by Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\LAPTOP INSIDE\AppData\Local\Temp\ipykernel_13420\2630204815.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Sex', data=df, palette='pastel')

# %%
sns.countplot(data=df, x='Pclass', palette='Set2')
plt.title('Count of Passengers by Class')
plt.xlabel('Passenger Class')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\LAPTOP INSIDE\AppData\Local\Temp\ipykernel_13420\1399482138.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Pclass', palette='Set2')

# %%
sns.countplot(data=df, x='Embarked', palette='Set3')
plt.title('Count of Passengers by Embarkation Port')
plt.xlabel('Embarked')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\LAPTOP INSIDE\AppData\Local\Temp\ipykernel_13420\2610004158.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Embarked', palette='Set3')

# %%
# Countplot for survival
sns.countplot(x='Survived', data=df, palette='Set1')
plt.xticks([0, 1], ['Did Not Survive', 'Survived'])
plt.title('Survival Count')
plt.xlabel('Survival Status')
plt.ylabel('Number of Passengers')
plt.show()
# Out:
# C:\Users\LAPTOP INSIDE\AppData\Local\Temp\ipykernel_13420\2211424277.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Survived', data=df, palette='Set1')

# %%
# Plot histogram for each numeric column using seaborn
numeric_cols = df.select_dtypes(include='number').columns

for col in numeric_cols:
    plt.figure(figsize=(6, 4))
    sns.histplot(df[col], kde=False, color='skyblue', edgecolor='black')
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.tight_layout()
    plt.show()

# %%
# scatter for all numaric data
sns.pairplot(df.select_dtypes(include=['float64', 'int64']), hue='Survived', palette='coolwarm')
plt.suptitle('Scatter Plots for All Numerical Features', y=1.02)
plt.show()

# %%
# Assuming your dataset is named 'df'
numeric_df = df.select_dtypes(include=['int64', 'float64'])
# Calculate the correlation
correlation = numeric_df.corr()
# Plotting the heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(correlation, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.show()

# %%
df['family_size'] = df['Parch'] + df['SibSp']

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Embarked  family_size
# 0      0         A/5 21171   7.2500        S            1
# 1      0          PC 17599  71.2833        C            1
# 2      0  STON/O2. 3101282   7.9250        S            0
# 3      0            113803  53.1000        S            1
# 4      0            373450   8.0500        S            0

# %%
df = df.drop(columns=['Parch', 'SibSp'])

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                                    Name  \
# 183          184         1       2               Becker, Master. Richard F
# 199          200         0       2  Yrois, Miss. Henriette ("Mrs Harbeck")
# 60            61         0       3                   Sirayanian, Mr. Orsen
# 675          676         0       3          Edvardsson, Mr. Gustaf Hjalmar
# 330          331         1       3                      McCoy, Miss. Agnes
#
#         Sex  Age  Ticket     Fare Embarked  family_size
# 183    male    1  230136  39.0000        S            3
# 199  female   24  248747  13.0000        S            0
# 60     male   22    2669   7.2292        C            0
# 675    male   18  349912   7.7750        S            0
# 330  female   29  367226  23.2500        Q            2

# %%
def get_family_type(size):
    if size == 0:
        return 'Alone'
    elif size <= 2:
        return 'Small'
    elif size <= 4:
        return 'Medium'
    else:
        return 'Large'
df['family_type'] = df['family_size'].apply(get_family_type)

# %%
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  \
# 0                            Braund, Mr. Owen Harris    male   22
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38
# 2                             Heikkinen, Miss. Laina  female   26
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35
# 4                           Allen, Mr. William Henry    male   35
#
#              Ticket     Fare Embarked  family_size family_type
# 0         A/5 21171   7.2500        S            1       Small
# 1          PC 17599  71.2833        C            1       Small
# 2  STON/O2. 3101282   7.9250        S            0       Alone
# 3            113803  53.1000        S            1       Small
# 4            373450   8.0500        S            0       Alone

# %%
df = df.drop(columns=['family_size'])

# %%
df.sample(2)
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 98            99         1       2  Doling, Mrs. John T (Ada Julia Bone)
# 522          523         0       3                    Lahoud, Mr. Sarkis
#
#         Sex  Age  Ticket    Fare Embarked family_type
# 98   female   34  231919  23.000        S       Small
# 522    male   29    2624   7.225        C       Alone

# %%
pd.crosstab(df['family_type'], df['Survived'], normalize='index') * 100
# Out:
# Survived             0          1
# family_type
# Alone        69.646182  30.353818
# Large        85.106383  14.893617
# Medium       45.454545  54.545455
# Small        43.726236  56.273764

# %%
pd.crosstab(df['Sex'], df['Survived'], normalize='index') * 100
# Out:
# Survived          0          1
# Sex
# female    25.796178  74.203822
# male      81.109185  18.890815

# %%
pd.crosstab(df['Pclass'], df['Survived'], normalize='index') * 100
# Out:
# Survived          0          1
# Pclass
# 1         37.037037  62.962963
# 2         52.717391  47.282609
# 3         75.763747  24.236253

# %%
pd.crosstab(df['Embarked'], df['Survived'], normalize='index') * 100
# Out:
# Survived          0          1
# Embarked
# C         44.642857  55.357143
# Q         61.038961  38.961039
# S         66.099071  33.900929

# %%
# Extract the title using regex
df['Title'] = df['Name'].str.extract('([A-Za-z]+)\.', expand=False)

# Check the unique titles
df['Title'].unique()
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\.'
# <>:2: SyntaxWarning: invalid escape sequence '\.'
# C:\Users\LAPTOP INSIDE\AppData\Local\Temp\ipykernel_7972\2765013934.py:2: SyntaxWarning: invalid escape sequence '\.'
#   df['Title'] = df['Name'].str.extract('([A-Za-z]+)\.', expand=False)
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Don', 'Rev', 'Dr', 'Mme', 'Ms',
#        'Major', 'Lady', 'Sir', 'Mlle', 'Col', 'Capt', 'Countess',
#        'Jonkheer'], dtype=object)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  \
# 0                            Braund, Mr. Owen Harris    male   22
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38
# 2                             Heikkinen, Miss. Laina  female   26
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35
# 4                           Allen, Mr. William Henry    male   35
#
#              Ticket     Fare Embarked family_type Title
# 0         A/5 21171   7.2500        S       Small    Mr
# 1          PC 17599  71.2833        C       Small   Mrs
# 2  STON/O2. 3101282   7.9250        S       Alone  Miss
# 3            113803  53.1000        S       Small   Mrs
# 4            373450   8.0500        S       Alone    Mr

# %%
title_mapping = {
    'Mr': 'Mr','Mrs': 'Mrs','Miss': 'Mrs', 'Ms': 'Mrs','Mme': 'Mrs','Mlle': 'Mrs','Master': 'Mr', 'Dr': 'Officers',
    'Rev': 'Officers','Col': 'Officers','Major': 'Officers','Capt': 'Officers','Sir': 'VIP','Lady': 'VIP','Don': 'VIP',
    'Jonkheer': 'VIP','the Countess': 'VIP'}
df['Title'] = df['Title'].map(title_mapping)
print(df['Title'].value_counts())
# Out:
# Title
# Mr          557
# Mrs         311
# Officers     18
# VIP           4
# Name: count, dtype: int64

# %%
pd.crosstab(df['Title'], df['Survived'], normalize='index') * 100
# Out:
# Survived          0          1
# Title
# Mr        81.328546  18.671454
# Mrs       26.045016  73.954984
# Officers  72.222222  27.777778
# VIP       50.000000  50.000000

# %%
df.sample(2)
# Out:
#      PassengerId  Survived  Pclass                         Name     Sex  Age  \
# 644          645         1       3       Baclini, Miss. Eugenie  female    0
# 861          862         0       2  Giles, Mr. Frederick Edward    male   21
#
#     Ticket     Fare Embarked family_type Title
# 644   2666  19.2583        C      Medium   Mrs
# 861  28134  11.5000        S       Small    Mr

# %%
df = df.drop(columns=['Name', 'PassengerId', 'Ticket'])

# %%
df.sample(2)
# Out:
#      Survived  Pclass     Sex  Age     Fare Embarked family_type Title
# 406         0       3    male   51   7.7500        S       Alone    Mr
# 362         0       3  female   45  14.4542        C       Small   Mrs

# %%
# Create fare_category
df['fare_category'] = pd.cut(df['Fare'],
                             bins=[0, 10, 50, 100, float('inf')],
                             labels=['Low', 'Medium', 'High', 'Very High'])

# Create age_category
df['age_category'] = pd.cut(df['Age'],
                            bins=[0, 12, 19, 59, float('inf')],
                            labels=['Child', 'Teen', 'Adult', 'Senior'])

# %%
df.sample(5)
# Out:
#      Survived  Pclass     Sex  Age      Fare Embarked family_type Title  \
# 85          1       3  female   33   15.8500        S      Medium   Mrs
# 638         0       3  female   41   39.6875        S       Large   Mrs
# 525         0       3    male   40    7.7500        Q       Alone    Mr
# 856         1       1  female   45  164.8667        S       Small   Mrs
# 20          0       2    male   35   26.0000        S       Alone    Mr
#
#     fare_category age_category
# 85         Medium        Adult
# 638        Medium        Adult
# 525           Low        Adult
# 856     Very High        Adult
# 20         Medium        Adult

# %%
df = df.drop(columns=['Fare', 'Age'])

# %%
df.sample(5)
# Out:
#      Survived  Pclass     Sex Embarked family_type     Title fare_category  \
# 398         0       2    male        S       Alone  Officers        Medium
# 511         0       3    male        S       Alone        Mr           Low
# 71          0       3  female        S       Large       Mrs        Medium
# 250         0       3    male        S       Alone        Mr           Low
# 269         1       1  female        S       Alone       Mrs     Very High
#
#     age_category
# 398        Adult
# 511        Adult
# 71          Teen
# 250        Adult
# 269        Adult

# %%
pd.crosstab([df['fare_category'], df['age_category']], df['Survived'], normalize='index') * 100
# Out:
# Survived                             0           1
# fare_category age_category
# Low           Teen           66.666667   33.333333
#               Adult          81.684982   18.315018
#               Senior         80.000000   20.000000
# Medium        Child          47.457627   52.542373
#               Teen           62.162162   37.837838
#               Adult          59.285714   40.714286
#               Senior         85.714286   14.285714
# High          Child           0.000000  100.000000
#               Teen           28.571429   71.428571
#               Adult          35.483871   64.516129
#               Senior         33.333333   66.666667
# Very High     Child          50.000000   50.000000
#               Teen           25.000000   75.000000
#               Adult          24.390244   75.609756
#               Senior        100.000000    0.000000

# %%
pd.crosstab(df['age_category'], df['Survived'], normalize='index') * 100
# Out:
# Survived              0          1
# age_category
# Child         46.774194  53.225806
# Teen          58.947368  41.052632
# Adult         63.480742  36.519258
# Senior        73.076923  26.923077

# %%
pd.crosstab(df['fare_category'], df['Survived'], normalize='index') * 100
# Out:
# Survived               0          1
# fare_category
# Low            79.439252  20.560748
# Medium         57.974684  42.025316
# High           34.579439  65.420561
# Very High      26.415094  73.584906

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Survived       891 non-null    int64
#  1   Pclass         891 non-null    int64
#  2   Sex            891 non-null    object
#  3   Embarked       891 non-null    object
#  4   family_type    891 non-null    object
#  5   Title          890 non-null    object
#  6   fare_category  876 non-null    category
#  7   age_category   884 non-null    category
# dtypes: category(2), int64(2), object(4)
# memory usage: 44.0+ KB

# %%
df['Sex'] = df['Sex'].astype('category')
df['Embarked'] = df['Embarked'].astype('category')
df['family_type'] = df['family_type'].astype('category')
df['Title'] = df['Title'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Survived       891 non-null    int64
#  1   Pclass         891 non-null    int64
#  2   Sex            891 non-null    category
#  3   Embarked       891 non-null    category
#  4   family_type    891 non-null    category
#  5   Title          890 non-null    category
#  6   fare_category  876 non-null    category
#  7   age_category   884 non-null    category
# dtypes: category(6), int64(2)
# memory usage: 20.3 KB

# %%
pd.get_dummies(df, columns=['Sex', 'Embarked', 'Title', 'family_type', 'fare_category', 'age_category','Pclass'], drop_first=True)
# Out:
#      Survived  Sex_male  Embarked_Q  Embarked_S  Title_Mrs  Title_Officers  \
# 0           0      True       False        True      False           False
# 1           1     False       False       False       True           False
# 2           1     False       False        True       True           False
# 3           1     False       False        True       True           False
# 4           0      True       False        True      False           False
# ..        ...       ...         ...         ...        ...             ...
# 886         0      True       False        True      False            True
# 887         1     False       False        True       True           False
# 888         0     False       False        True       True           False
# 889         1      True       False       False      False           False
# 890         0      True        True       False      False           False
#
#      Title_VIP  family_type_Large  family_type_Medium  family_type_Small  \
# 0        False              False               False               True
# 1        False              False               False               True
# 2        False              False               False              False
# 3        False              False               False               True
# 4        False              False               False              False
# ..         ...                ...                 ...                ...
# 886      False              False               False              False
# 887      False              False               False              False
# 888      False              False                True              False
# 889      False              False               False              False
# 890      False              False               False              False
#
#      fare_category_Medium  fare_category_High  fare_category_Very High  \
# 0                   False               False                    False
# 1                   False                True                    False
# 2                   False               False                    False
# 3                   False                True                    False
# 4                   False               False                    False
# ..                    ...                 ...                      ...
# 886                  True               False                    False
# 887                  True               False                    False
# 888                  True               False                    False
# 889                  True               False                    False
# 890                 False               False                    False
#
#      age_category_Teen  age_category_Adult  age_category_Senior  Pclass_2  \
# 0                False                True                False     False
# 1                False                True                False     False
# 2                False                True                False     False
# 3                False                True                False     False
# 4                False                True                False     False
# ..                 ...                 ...                  ...       ...
# 886              False                True                False      True
# 887               True               False                False     False
# 888              False                True                False     False
# 889              False                True                False     False
# 890              False                True                False     False
#
#      Pclass_3
# 0        True
# 1       False
# 2        True
# 3       False
# 4        True
# ..        ...
# 886     False
# 887     False
# 888      True
# 889     False
# 890      True
#
# [891 rows x 18 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Survived       891 non-null    int64
#  1   Pclass         891 non-null    int64
#  2   Sex            891 non-null    category
#  3   Embarked       891 non-null    category
#  4   family_type    891 non-null    category
#  5   Title          890 non-null    category
#  6   fare_category  876 non-null    category
#  7   age_category   884 non-null    category
# dtypes: category(6), int64(2)
# memory usage: 20.3 KB

# %%
import joblib
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, roc_auc_score

# Assuming 'df' is your preprocessed DataFrame with the necessary columns

# Prepare features (X) and target (y)
X = df.drop(columns=['Survived'])  # Features
y = df['Survived']  # Target

# Split the data into 80% train and 20% test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# One-Hot Encoding for categorical features
X_train_encoded = pd.get_dummies(X_train, drop_first=True)
X_test_encoded = pd.get_dummies(X_test, drop_first=True)

# Ensure the train and test sets have the same columns (in case of different categories in training/test data)
X_train_encoded, X_test_encoded = X_train_encoded.align(X_test_encoded, join='left', axis=1, fill_value=0)

# Standardize the features (important for most models)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_encoded)
X_test_scaled = scaler.transform(X_test_encoded)

# Initialize the Random Forest model
rf_model = RandomForestClassifier(n_estimators=100, random_state=0)

# Train the model
rf_model.fit(X_train_scaled, y_train)

# Predict on the test set
y_pred = rf_model.predict(X_test_scaled)

# Evaluate the model using accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy * 100:.2f}%")

# Generate confusion matrix
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(cm)

# Classification report with precision, recall, and F1-score
classification_rep = classification_report(y_test, y_pred)
print("Classification Report:")
print(classification_rep)

# ROC AUC score
roc_auc = roc_auc_score(y_test, rf_model.predict_proba(X_test_scaled)[:, 1])
print(f"ROC AUC Score: {roc_auc:.2f}")

# Save the model using joblib
joblib.dump(rf_model, 'random_forest_model.joblib')

# Save the scaler using joblib
joblib.dump(scaler, 'scaler.joblib')

# To load the model later
rf_model = joblib.load('random_forest_model.joblib')
scaler = joblib.load('scaler.joblib')
# Out:
# Accuracy: 84.92%
# Confusion Matrix:
# [[100  10]
#  [ 17  52]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.91      0.88       110
#            1       0.84      0.75      0.79        69
#
#     accuracy                           0.85       179
#    macro avg       0.85      0.83      0.84       179
# weighted avg       0.85      0.85      0.85       179
#
# ROC AUC Score: 0.88

# %%
# After preparing X_train:
joblib.dump(X_train.columns.tolist(), 'feature_columns.joblib')
# Out:
# ['feature_columns.joblib']

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Plot the bar plot for 'Embarked' feature
df['family_size'].value_counts().plot(kind='bar')

# Add labels and title
plt.xlabel('Port of Embarkation')
plt.ylabel('Number of Passengers')
plt.title('Number of Passengers per Embarked Port')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Create the 'Family_type' column based on SibSp and Parch (family size)
titanic['Family_type'] = titanic['SibSp'] + titanic['Parch']
titanic['Family_type'] = titanic['Family_type'].apply(lambda x: 'Alone' if x == 0 else 'With Family')

# Now, create the grouped bar plot
plt.figure(figsize=(4, 5))
sns.countplot(data=titanic, x='Family_type', hue='Survived')

# Add labels and title
plt.xlabel('Family Type')
plt.ylabel('Number of Passengers')
plt.title('Comparison of Survived vs Family Type')
plt.legend(title='Survived', loc='upper left', labels=['Not Survived', 'Survived'])
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the Titanic dataset (make sure the path is correct)


# Create the 'Family_type' column based on SibSp and Parch (family size)
titanic['Family_type'] = titanic['SibSp'] + titanic['Parch']
titanic['Family_type'] = titanic['Family_type'].apply(lambda x: 'Alone' if x == 0 else 'With Family')

# Count the occurrences of each combination of Family_type and Survived
survival_counts = titanic.groupby(['Family_type', 'Survived']).size().unstack()

# Plot the stacked bar plot
survival_counts.plot(kind='bar', stacked=True, figsize=(4, 3), color=['red', 'green'])

# Add labels and title
plt.xlabel('Family Type')
plt.ylabel('Number of Passengers')
plt.title('Comparison of Survived vs Family Type (Stacked)')
plt.xticks(rotation=0)  # Keep the labels horizontal for readability
plt.legend(title='Survived', labels=['Not Survived', 'Survived'])
plt.show()

# %%
# Example for a binned column (e.g., Age binned into categories)
df['Age_binned'] = pd.cut(df['Age'], bins=[0, 18, 35, 60, 100])
df['Age_binned'].value_counts()
# Out:
# Age_binned
# (18, 35]     535
# (35, 60]     195
# (0, 18]      132
# (60, 100]     22
# Name: count, dtype: int64

# %%
df['Age'].value_counts()
# Out:
# Age
# 29    197
# 24     31
# 22     27
# 28     27
# 30     27
#      ...
# 66      1
# 53      1
# 80      1
# 12      1
# 74      1
# Name: count, Length: 71, dtype: int64

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 272          273         1       2  Mellinger, Mrs. (Elizabeth Anne Maidment)
# 747          748         1       2                      Sinkkonen, Miss. Anna
# 62            63         0       1                Harris, Mr. Henry Birkhardt
# 482          483         0       3                   Rouse, Mr. Richard Henry
# 835          836         1       1                Compton, Miss. Sara Rebecca
#
#         Sex  Age  SibSp  Parch    Ticket     Fare Embarked Age_binned
# 272  female   41      0      1    250644  19.5000        S   (35, 60]
# 747  female   30      0      0    250648  13.0000        S   (18, 35]
# 62     male   45      1      0     36973  83.4750        S   (35, 60]
# 482    male   50      0      0  A/5 3594   8.0500        S   (35, 60]
# 835  female   39      1      1  PC 17756  83.1583        C   (35, 60]

# %%
# Select only numerical columns
df_numeric = df.select_dtypes(include=['number'])

# Calculate quantiles (e.g., 25th, 50th, 75th percentiles) for numeric columns
quantiles = df_numeric.quantile([0.25, 0.5, 0.75])
print(quantiles)
# Out:
#       PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0.25        223.5       0.0     2.0  22.0    0.0    0.0   7.9104
# 0.50        446.0       0.0     3.0  29.0    0.0    0.0  14.4542
# 0.75        668.5       1.0     3.0  35.0    1.0    0.0  31.0000

# %%
# Interquartile Range
IQR = df_numeric.quantile(0.5) - df_numeric.quantile(0.25)
print(IQR)
# Out:
# PassengerId    222.5000
# Survived         0.0000
# Pclass           1.0000
# Age              7.0000
# SibSp            0.0000
# Parch            0.0000
# Fare             6.5438
# dtype: float64

# %%
value_counts = df['Title'].value_counts()
print(value_counts)
# Out:
# Title
# Mr          517
# Miss        182
# Mrs         125
# Master       40
# Dr            7
# Rev           6
# Mlle          2
# Major         2
# Col           2
# Countess      1
# Capt          1
# Ms            1
# Sir           1
# Lady          1
# Mme           1
# Don           1
# Jonkheer      1
# Name: count, dtype: int64

# %%
frequency_distribution = df['Title'].value_counts(normalize=True)
print(frequency_distribution)
# Out:
# Title
# Mr          0.580247
# Miss        0.204265
# Mrs         0.140292
# Master      0.044893
# Dr          0.007856
# Rev         0.006734
# Mlle        0.002245
# Major       0.002245
# Col         0.002245
# Countess    0.001122
# Capt        0.001122
# Ms          0.001122
# Sir         0.001122
# Lady        0.001122
# Mme         0.001122
# Don         0.001122
# Jonkheer    0.001122
# Name: proportion, dtype: float64

# %%
categorical_description = df.describe(include=['object'])
print(categorical_description)
# Out:
#                            Name   Sex  Ticket Embarked Title
# count                       891   891     891      891   891
# unique                      891     2     681        3    17
# top     Braund, Mr. Owen Harris  male  347082        S    Mr
# freq                          1   577       7      646   517

# %%
mode_value = df['Title'].mode()[0]
print(mode_value)
# Out:
# Mr

# %%
cardinality = df['Title'].nunique()
print(cardinality)
# Out:
# 17

# %%
from scipy.stats import chi2_contingency

crosstab = pd.crosstab(df['Survived'], df['Pclass'])
chi2, p, _, _ = chi2_contingency(crosstab)
print(crosstab)
# Out:
# Pclass      1   2    3
# Survived
# 0          80  97  372
# 1         136  87  119

# %%
import pandas as pd

# Assuming df is your Titanic 

# Group by Pclass and Sex, then aggregate by summing the 'Survived' column to count survivors
grouped_data = df.groupby(['Pclass', 'Sex'])['Survived'].sum()

print(grouped_data)
# Out:
# Pclass  Sex
# 1       female    91
#         male      45
# 2       female    70
#         male      17
# 3       female    72
#         male      47
# Name: Survived, dtype: int64
